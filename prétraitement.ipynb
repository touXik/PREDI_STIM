# %%
import pandas as pd 
import numpy as np

# %%
xl = pd.ExcelFile("Data/Matthieu_Soumaya_Dec2025.xlsx")

# Afficher les noms des feuilles
# print(xl.sheet_names)
# ['Feuille1', 'Feuille2', 'Feuille3']
print(f"Nombre de feuille : ",{len(xl.sheet_names)})
# une par ligne
for nom in xl.sheet_names:
    print(nom)
# Out:
#  Nombre de feuille :  {28}
# AGE_SEX_DUREE
# Poids_Taille V0
# Poids_Taille_V1_3_5
#  Mutation_GBA_LRRK2
# UPDRS_IV
# UPDRSIII_COMPLET_V0_V1
# UPDRSIII_COMPLET_V3_V5
# UPDRSIII_TOTAUX
# ECMP
# QUIP
# UPPS
# MOCA_V0_V3
# MOCA_V1_V5
# HAMD
# HAMA
# LARS
# PDQ39
# DIGITSMT_TRAILMT_DKEFS
# CONSO_SPECIFIQUE
# Feuil4
# LEDD
# Feuil1
# Feuil2
# PSYCHOTROPES
# AUTRE_PARKINSON
# FREQUENCE_V1_3_5
# DATES_VISITE
# FIN_ETUDE

# %% [markdown]
# ## Feuille infos statiques

# %%
df_00 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="AGE_SEX_DUREE")
print(df_00.shape)
df_00.head()
# Out:
# (836, 12)
#                              SUBJID                        D_SCREEN  \
# 0  Subject Identifier for the Study  date de la visite de screening
# 1                            01-001                      18/11/2013
# 2                            01-002                      13/01/2014
# 3                            01-003                      04/03/2014
# 4                            01-004                      12/05/2014
#
#                  DDN  AGE  SEXE               D_1ER_SYMPT  \
# 0  date de naissance  âge  sexe  année premiers symptomes
# 1            02/1946   67     1                      1998
# 2            01/1954   59     1                      2006
# 3            02/1953   61     1                      2001
# 4            08/1948   65     2                      1998
#
#                               D_DIAG                            D_LDOPA  \
# 0  année du diagnostic de la maladie  année d'introduction de la L-DOPA
# 1                               1999                               2000
# 2                               2006                               2006
# 3                               2001                               2003
# 4                               2000                               2003
#
#                                          D_TTT_DOPAM  \
# 0  année d'introduction du traitement dopaminergique
# 1                                               2000
# 2                                               2006
# 3                                               2001
# 4                                               2000
#
#                                   D_FLUCTU_MOTR  \
# 0  année d'apparition des fluctuations motrices
# 1                                          2002
# 2                                          2011
# 3                                          2004
# 4                                          2003
#
#                                    D_FLUCTU_NONMOTR  \
# 0  année d'apparition des fluctuations non motrices
# 1                                              2000
# 2                                                .K
# 3                                                .K
# 4                                              2003
#
#                          D_DYSKINESIE
# 0  année d'apparition des dyskinésies
# 1                                  .D
# 2                                  .K
# 3                                2004
# 4                                2003

# %%
df_01 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name=" Mutation_GBA_LRRK2")
display(df_01.head())
print(df_01.shape)
# Out:
#    SUBJID      DDN   AGE  SEXE Mut_GBA alias_GBA
# 0  01-001  févr-46  67.0   1.0     NaN       NaN
# 1  01-002  janv-54  59.0   1.0     NaN       NaN
# 2  01-003  févr-53  61.0   1.0     NaN       NaN
# 3  01-004  août-48  65.0   2.0     NaN       NaN
# 4  01-005   oct-48  65.0   1.0     NaN       NaN
# (832, 6)

# %%
df_00_01 = pd.merge(df_00, df_01, on="SUBJID", how="left")

# %%
df_00_01
# Out:
#                                SUBJID                        D_SCREEN  \
# 0    Subject Identifier for the Study  date de la visite de screening
# 1                              01-001                      18/11/2013
# 2                              01-002                      13/01/2014
# 3                              01-003                      04/03/2014
# 4                              01-004                      12/05/2014
# ..                                ...                             ...
# 831                            20-025                      21/06/2018
# 832                            20-026                      04/07/2018
# 833                            20-027                      12/07/2018
# 834                            20-028                      08/11/2018
# 835                            20-029                      28/11/2018
#
#                  DDN_x AGE_x SEXE_x               D_1ER_SYMPT  \
# 0    date de naissance   âge   sexe  année premiers symptomes
# 1              02/1946    67      1                      1998
# 2              01/1954    59      1                      2006
# 3              02/1953    61      1                      2001
# 4              08/1948    65      2                      1998
# ..                 ...   ...    ...                       ...
# 831            09/1956    61      2                      2007
# 832            07/1958    59      1                      2012
# 833            11/1953    64      1                      2011
# 834            10/1949    69      2                      2010
# 835            08/1948    70      2                      2005
#
#                                 D_DIAG                            D_LDOPA  \
# 0    année du diagnostic de la maladie  année d'introduction de la L-DOPA
# 1                                 1999                               2000
# 2                                 2006                               2006
# 3                                 2001                               2003
# 4                                 2000                               2003
# ..                                 ...                                ...
# 831                               2007                               2007
# 832                               2012                               2012
# 833                               2012                               2015
# 834                               2011                               2015
# 835                               2007                                 .A
#
#                                            D_TTT_DOPAM  \
# 0    année d'introduction du traitement dopaminergique
# 1                                                 2000
# 2                                                 2006
# 3                                                 2001
# 4                                                 2000
# ..                                                 ...
# 831                                               2007
# 832                                               2012
# 833                                               2013
# 834                                               2011
# 835                                                 .A
#
#                                     D_FLUCTU_MOTR  \
# 0    année d'apparition des fluctuations motrices
# 1                                            2002
# 2                                            2011
# 3                                            2004
# 4                                            2003
# ..                                            ...
# 831                                          2016
# 832                                          2015
# 833                                          2017
# 834                                          2016
# 835                                          2016
#
#                                      D_FLUCTU_NONMOTR  \
# 0    année d'apparition des fluctuations non motrices
# 1                                                2000
# 2                                                  .K
# 3                                                  .K
# 4                                                2003
# ..                                                ...
# 831                                              2016
# 832                                              2016
# 833                                                .A
# 834                                              2016
# 835                                              2016
#
#                            D_DYSKINESIE    DDN_y  AGE_y  SEXE_y Mut_GBA  \
# 0    année d'apparition des dyskinésies      NaN    NaN     NaN     NaN
# 1                                    .D  févr-46   67.0     1.0     NaN
# 2                                    .K  janv-54   59.0     1.0     NaN
# 3                                  2004  févr-53   61.0     1.0     NaN
# 4                                  2003  août-48   65.0     2.0     NaN
# ..                                  ...      ...    ...     ...     ...
# 831                                2017  sept-56   61.0     2.0     NaN
# 832                                2017  juil-58   59.0     1.0     NaN
# 833                                2018   nov-53   64.0     1.0     GBA
# 834                                2017   oct-49   69.0     2.0     NaN
# 835                                  .A  août-48   70.0     2.0     NaN
#
#     alias_GBA
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 831       NaN
# 832       NaN
# 833      R48W
# 834       NaN
# 835       NaN
#
# [836 rows x 17 columns]

# %%
# ══════════════════════════════════════════════════════════
# Afficher les colonnes dupliquées : type + % NaN
# ══════════════════════════════════════════════════════════
print("=" * 65)
print(f"{'Colonne':<20} {'Type _x':<12} {'Type _y':<12} {'NaN _x':>8} {'NaN _y':>8}")
print("=" * 65)

for col_x in cols_x:
    col_y   = col_x.replace("_x", "_y")
    col_nom = col_x.replace("_x", "")
    nan_x   = df_00_01[col_x].isna().mean() * 100
    nan_y   = df_00_01[col_y].isna().mean() * 100
    print(f"{col_nom:<20} {str(df_00_01[col_x].dtype):<12} {str(df_00_01[col_y].dtype):<12} {nan_x:>7.1f}% {nan_y:>7.1f}%")
# Out:
# =================================================================
# Colonne              Type _x      Type _y        NaN _x   NaN _y
# =================================================================
# DDN                  object       object           0.1%     0.8%
# AGE                  object       float64          0.2%     1.8%
# SEXE                 object       float64          0.2%     1.3%

# %%
# ══════════════════════════════════════════════════════════
#Harmoniser les types (_y → même type que _x)
# ══════════════════════════════════════════════════════════
for col_x in cols_x:
    col_y = col_x.replace("_x", "_y")
    try:
        df_00_01[col_y] = df_00_01[col_y].astype(df_00_01[col_x].dtype)
    except (ValueError, TypeError):
        # Si la conversion échoue, on force en string pour pouvoir comparer
        df_00_01[col_x] = df_00_01[col_x].astype(str)
        df_00_01[col_y] = df_00_01[col_y].astype(str)

# %%
df_00_01
# Out:
#                                SUBJID                        D_SCREEN  \
# 0    Subject Identifier for the Study  date de la visite de screening
# 1                              01-001                      18/11/2013
# 2                              01-002                      13/01/2014
# 3                              01-003                      04/03/2014
# 4                              01-004                      12/05/2014
# ..                                ...                             ...
# 831                            20-025                      21/06/2018
# 832                            20-026                      04/07/2018
# 833                            20-027                      12/07/2018
# 834                            20-028                      08/11/2018
# 835                            20-029                      28/11/2018
#
#                  DDN_x AGE_x SEXE_x               D_1ER_SYMPT  \
# 0    date de naissance   âge   sexe  année premiers symptomes
# 1              02/1946    67      1                      1998
# 2              01/1954    59      1                      2006
# 3              02/1953    61      1                      2001
# 4              08/1948    65      2                      1998
# ..                 ...   ...    ...                       ...
# 831            09/1956    61      2                      2007
# 832            07/1958    59      1                      2012
# 833            11/1953    64      1                      2011
# 834            10/1949    69      2                      2010
# 835            08/1948    70      2                      2005
#
#                                 D_DIAG                            D_LDOPA  \
# 0    année du diagnostic de la maladie  année d'introduction de la L-DOPA
# 1                                 1999                               2000
# 2                                 2006                               2006
# 3                                 2001                               2003
# 4                                 2000                               2003
# ..                                 ...                                ...
# 831                               2007                               2007
# 832                               2012                               2012
# 833                               2012                               2015
# 834                               2011                               2015
# 835                               2007                                 .A
#
#                                            D_TTT_DOPAM  \
# 0    année d'introduction du traitement dopaminergique
# 1                                                 2000
# 2                                                 2006
# 3                                                 2001
# 4                                                 2000
# ..                                                 ...
# 831                                               2007
# 832                                               2012
# 833                                               2013
# 834                                               2011
# 835                                                 .A
#
#                                     D_FLUCTU_MOTR  \
# 0    année d'apparition des fluctuations motrices
# 1                                            2002
# 2                                            2011
# 3                                            2004
# 4                                            2003
# ..                                            ...
# 831                                          2016
# 832                                          2015
# 833                                          2017
# 834                                          2016
# 835                                          2016
#
#                                      D_FLUCTU_NONMOTR  \
# 0    année d'apparition des fluctuations non motrices
# 1                                                2000
# 2                                                  .K
# 3                                                  .K
# 4                                                2003
# ..                                                ...
# 831                                              2016
# 832                                              2016
# 833                                                .A
# 834                                              2016
# 835                                              2016
#
#                            D_DYSKINESIE    DDN_y AGE_y SEXE_y Mut_GBA  \
# 0    année d'apparition des dyskinésies      NaN   NaN    NaN     NaN
# 1                                    .D  févr-46  67.0    1.0     NaN
# 2                                    .K  janv-54  59.0    1.0     NaN
# 3                                  2004  févr-53  61.0    1.0     NaN
# 4                                  2003  août-48  65.0    2.0     NaN
# ..                                  ...      ...   ...    ...     ...
# 831                                2017  sept-56  61.0    2.0     NaN
# 832                                2017  juil-58  59.0    1.0     NaN
# 833                                2018   nov-53  64.0    1.0     GBA
# 834                                2017   oct-49  69.0    2.0     NaN
# 835                                  .A  août-48  70.0    2.0     NaN
#
#     alias_GBA
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 831       NaN
# 832       NaN
# 833      R48W
# 834       NaN
# 835       NaN
#
# [836 rows x 17 columns]

# %%
# # ══════════════════════════════════════════════════════════
# # Comparer les valeurs et afficher la similarité
# # ══════════════════════════════════════════════════════════
# print("\n" + "=" * 50)
# print(f"{'Colonne':<20} {'Similarité':>12} {'Statut'}")
# print("=" * 50)

# resultats = {}
# for col_x in cols_x:
#     col_y   = col_x.replace("_x", "_y")
#     col_nom = col_x.replace("_x", "")

#     # Comparer uniquement les lignes où les deux sont non-NaN
#     masque  = df_00_01[col_x].notna() & df_00_01[col_y].notna()
#     n_total = masque.sum()

#     if n_total == 0:
#         similarite = 0.0
#     else:
#         n_egaux    = (df_00_01.loc[masque, col_x] == df_00_01.loc[masque, col_y]).sum()
#         similarite = (n_egaux / n_total) * 100

#     statut = "identiques" if similarite == 100 else f"  {100-similarite:.1f}% différences"
#     print(f"{col_nom:<20} {similarite:>11.1f}% {statut}")
#     resultats[col_nom] = similarite
# Out:
# ==================================================
# Colonne                Similarité Statut
# ==================================================
# DDN                          0.0%   100.0% différences
# AGE                          0.0%   100.0% différences
# SEXE                         0.0%   100.0% différences

# %%
for col_x in cols_x:
    col_y   = col_x.replace("_x", "_y")
    col_nom = col_x.replace("_x", "")

    # Lignes où _x est NaN mais _y est rempli
    masque = df_00_01[col_x].isna() & df_00_01[col_y].notna()
    lignes = df_00_01[masque][["SUBJID", col_x, col_y]]

    if len(lignes) > 0:
        print(f"\n{'='*50}")
        print(f"{col_nom} — {len(lignes)} ligne(s) à combler")
        print(lignes.to_string(index=False))

# %%
# ══════════════════════════════════════════════════════════
#  Fusionner et combler les NaN
# ══════════════════════════════════════════════════════════
for col_x in cols_x:
    col_y   = col_x.replace("_x", "_y")
    col_nom = col_x.replace("_x", "")
    # Colonnes identiques → on garde _x et on comble ses NaN avec _y
    df_00_01[col_nom] = df_00_01[col_x].fillna(df_00_01[col_y])
    df_00_01.drop(columns=[col_x, col_y], inplace=True)
    print(f"{col_nom} : fusionné (NaN comblés depuis _y)")
# Out:
# DDN : fusionné (NaN comblés depuis _y)
# AGE : fusionné (NaN comblés depuis _y)
# SEXE : fusionné (NaN comblés depuis _y)

# %%
# supprimer la premiére ligne 
df_00_01 = df_00_01.iloc[1:].reset_index(drop=True)


# # Ignorer directement à la lecture
# df = pd.read_excel("fichier.xlsx", skiprows=1)

# %%
df_00_01
# Out:
#      SUBJID    D_SCREEN D_1ER_SYMPT D_DIAG D_LDOPA D_TTT_DOPAM D_FLUCTU_MOTR  \
# 0    01-001  18/11/2013        1998   1999    2000        2000          2002
# 1    01-002  13/01/2014        2006   2006    2006        2006          2011
# 2    01-003  04/03/2014        2001   2001    2003        2001          2004
# 3    01-004  12/05/2014        1998   2000    2003        2000          2003
# 4    01-005  16/06/2014        1997   1998    2012        1998          2012
# ..      ...         ...         ...    ...     ...         ...           ...
# 830  20-025  21/06/2018        2007   2007    2007        2007          2016
# 831  20-026  04/07/2018        2012   2012    2012        2012          2015
# 832  20-027  12/07/2018        2011   2012    2015        2013          2017
# 833  20-028  08/11/2018        2010   2011    2015        2011          2016
# 834  20-029  28/11/2018        2005   2007      .A          .A          2016
#
#     D_FLUCTU_NONMOTR D_DYSKINESIE Mut_GBA alias_GBA      DDN AGE SEXE
# 0               2000           .D     NaN       NaN  02/1946  67    1
# 1                 .K           .K     NaN       NaN  01/1954  59    1
# 2                 .K         2004     NaN       NaN  02/1953  61    1
# 3               2003         2003     NaN       NaN  08/1948  65    2
# 4                 .A           .A     NaN       NaN  10/1948  65    1
# ..               ...          ...     ...       ...      ...  ..  ...
# 830             2016         2017     NaN       NaN  09/1956  61    2
# 831             2016         2017     NaN       NaN  07/1958  59    1
# 832               .A         2018     GBA      R48W  11/1953  64    1
# 833             2016         2017     NaN       NaN  10/1949  69    2
# 834             2016           .A     NaN       NaN  08/1948  70    2
#
# [835 rows x 14 columns]

# %%
df_00_01.to_excel("Output/info_statiques.xlsx",index=False)

# %% [markdown]
# ## Feuille Bilan

# %% [markdown]
# ### Séparer les Feuilles

# %% [markdown]
# #### Poids_Taille_V1_3_5

# %%
df_v1_2_3 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="Poids_Taille_V1_3_5")
print(df_v1_2_3.shape)
df_v1_2_3.head()
# Out:
# (2506, 8)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-002                 TM
#
#                        TITRE               DATE  POIDS           POIDS_NR  \
# 0                      titre  Date de la visite  poids  poids non realisé
# 1   Visite Bilan à 1 an - V1                NaN    NaN                NaN
# 2  Visite Bilan à 3 ans - V3                NaN    NaN                NaN
# 3  Visite Bilan à 5 ans - V5                NaN    NaN                NaN
# 4   Visite Bilan à 1 an - V1                NaN    NaN                NaN
#
#    TAILLE           TAILLE_NR
# 0  taille  taille non réalisé
# 1     NaN                 NaN
# 2     NaN                 NaN
# 3     NaN                 NaN
# 4     NaN                 NaN

# %%
df_v1_2_3["TITRE"].value_counts()
# Out:
# TITRE
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# titre                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_v1_Poids_Taille = df_v1_2_3[df_v1_2_3["TITRE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_Poids_Taille = df_v1_2_3[df_v1_2_3["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_Poids_Taille = df_v1_2_3[df_v1_2_3["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %%
df_v1
# Out:
#      SUBJID INIT_PAT                     TITRE        DATE POIDS POIDS_NR  \
# 0    01-001       SR  Visite Bilan à 1 an - V1         NaN   NaN      NaN
# 1    01-002       TM  Visite Bilan à 1 an - V1         NaN   NaN      NaN
# 2    01-003       SJ  Visite Bilan à 1 an - V1         NaN   NaN      NaN
# 3    01-004       DJ  Visite Bilan à 1 an - V1         NaN   NaN      NaN
# 4    01-005       LB  Visite Bilan à 1 an - V1  25/01/2016    82      NaN
# ..      ...      ...                       ...         ...   ...      ...
# 830  20-025       DA  Visite Bilan à 1 an - V1  22/09/2021    75      NaN
# 831  20-026       ME  Visite Bilan à 1 an - V1          .A   NaN        1
# 832  20-027       RP  Visite Bilan à 1 an - V1         NaN   NaN      NaN
# 833  20-028       DN  Visite Bilan à 1 an - V1  10/11/2021    82      NaN
# 834  20-029       DA  Visite Bilan à 1 an - V1         NaN   NaN      NaN
#
#     TAILLE TAILLE_NR
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      169       NaN
# ..     ...       ...
# 830    170       NaN
# 831    NaN         1
# 832    NaN       NaN
# 833    162       NaN
# 834    NaN       NaN
#
# [835 rows x 8 columns]

# %% [markdown]
# #### UPDRS_IV

# %%
df_UPDRS_IV = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="UPDRS_IV")
print(df_UPDRS_IV.shape)
df_UPDRS_IV.head()
# Out:
# (3341, 10)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-001                 SR
#
#                        TITRE     MDSUPDRSPARTIE4      MDSUPDRSPARTIE41  \
# 0                      titre  MDS-UPDRS partie 4  MDS-UPDRS partie 4.1
# 1        Visite de screening                  10                Minime
# 2   Visite Bilan à 1 an - V1                 NaN                   NaN
# 3  Visite Bilan à 3 ans - V3                 NaN                   NaN
# 4  Visite Bilan à 5 ans - V5                 NaN                   NaN
#
#        MDSUPDRSPARTIE42      MDSUPDRSPARTIE43      MDSUPDRSPARTIE44  \
# 0  MDS-UPDRS partie 4.2  MDS-UPDRS partie 4.3  MDS-UPDRS partie 4.4
# 1                Modéré                 Léger                Modéré
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#        MDSUPDRSPARTIE45      MDSUPDRSPARTIE46
# 0  MDS-UPDRS partie 4.5  MDS-UPDRS partie 4.6
# 1                Minime                Normal
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN

# %%
df_UPDRS_IV["TITRE"].value_counts()
# Out:
# TITRE
# Visite de screening          835
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# titre                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_V0_UPDRS = df_UPDRS_IV[df_UPDRS_IV["TITRE"] == "Visite de screening"].reset_index(drop=True)
df_v1_UPDRS = df_UPDRS_IV[df_UPDRS_IV["TITRE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_UPDRS = df_UPDRS_IV[df_UPDRS_IV["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_UPDRS = df_UPDRS_IV[df_UPDRS_IV["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### UPDRSIII_COMPLET_V0_V1

# %%
df_UPDRSIII_COMPLET_V0_V1 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="UPDRSIII_COMPLET_V0_V1")
print(df_UPDRSIII_COMPLET_V0_V1.shape)
df_UPDRSIII_COMPLET_V0_V1.head()
# Out:
# (836, 417)
#                              SUBJID                            V12H_APRES  \
# 0  Subject Identifier for the Study  réalisation après 12h d'arret L-Dopa
# 1                            01-001                                     1
# 2                            01-002                                     1
# 3                            01-003                                     1
# 4                            01-004                                     1
#
#                                   DEMIVIE_AGONISTE                   H_LDOPA  \
# 0  réalisation après 5 demie-vies d'arret agoniste  heure de prise de L Dopa
# 1                                                1                     09:00
# 2                                                1                     09:47
# 3                                               .K                     09:00
# 4                                                1                     09:25
#
#        DOSE_LDOPA      OFF_H       ON_H15       ON_H30       ON_H45  \
# 0  dose de L Dopa  off heure  on 15 heure  on 30 heure  on 45 heure
# 1             200      09:00        09:15        09:30        09:45
# 2             350      09:46        10:10        10:25        10:43
# 3             400      08:50        09:17        09:34        09:54
# 4             500      09:20        09:46        10:06        10:30
#
#         ON_H60  ...  OFFON_SS_TOT1_CALC  ON_SS_TOT1_CALC  ONOFF_SS_TOT2_CALC  \
# 0  on 60 heure  ...  OFFON_ss_tot1_calc  ON_ss_tot1_calc  ONOFF_ss_tot2_calc
# 1        10:00  ...                 NaN              NaN                 NaN
# 2        11:03  ...                 NaN              NaN                 NaN
# 3        10:14  ...                 NaN              NaN                 NaN
# 4        10:45  ...                 NaN              NaN                 NaN
#
#    OFF_SS_TOT2_CALC  OFFON_SS_TOT2_CALC  ON_SS_TOT2_CALC  ONOFF_TOTALCALC  \
# 0  OFF_ss_tot2_calc  OFFON_ss_tot2_calc  ON_ss_tot2_calc  ONOFF_TOTALCALC
# 1               NaN                 NaN              NaN              NaN
# 2               NaN                 NaN              NaN              NaN
# 3               NaN                 NaN              NaN              NaN
# 4               NaN                 NaN              NaN              NaN
#
#    OFF_TOTALCALC  OFFON_TOTALCALC  ON_TOTALCALC
# 0  OFF_TOTALCALC  OFFON_TOTALCALC  ON_TOTALCALC
# 1            NaN              NaN           NaN
# 2            NaN              NaN           NaN
# 3            NaN              NaN           NaN
# 4            NaN              NaN           NaN
#
# [5 rows x 417 columns]

# %% [markdown]
# #### UPDRSIII_COMPLET_V3_V5

# %%
df_UPDRSIII_COMPLET_V3_V5 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="UPDRSIII_COMPLET_V3_V5 ")
print(df_UPDRSIII_COMPLET_V3_V5.shape)
df_UPDRSIII_COMPLET_V3_V5.head()
# Out:
# (1671, 41)
#                              SUBJID                      VISIT  \
# 0  Subject Identifier for the Study                      Visit
# 1                            01-001  Visite Bilan à 3 ans - V3
# 2                            01-001  Visite Bilan à 5 ans - V5
# 3                            01-002  Visite Bilan à 3 ans - V3
# 4                            01-002  Visite Bilan à 5 ans - V5
#
#                                     H_DERNPRISE_DOPA             ON_H  \
# 0  heure de dernière prise de traitement dopamine...  heure en minute
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#   ON_PAROLE          ON_EXP_FAC        ON_COU     ON_MSDROIT_RIG  \
# 0    parole  expression faciale  rigidité cou  rigidité MS droit
# 1       NaN                 NaN           NaN                NaN
# 2       NaN                 NaN           NaN                NaN
# 3       NaN                 NaN           NaN                NaN
# 4       NaN                 NaN           NaN                NaN
#
#         ON_MSGCHE_RIG     ON_MIDROIT_RIG  ...  \
# 0  rigidité MS gauche  rigidité MI droit  ...
# 1                 NaN                NaN  ...
# 2                 NaN                NaN  ...
# 3                 NaN                NaN  ...
# 4                 NaN                NaN  ...
#
#                ON_TREMBLMAIN_MSDROIT                ON_TREMBLMAIN_MSGCHE  \
# 0  tremblement action mains MS droit  tremblement action mains MS gauche
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#                         ON_LEVRE_AMPLI_TREMBL  \
# 0  amplitude tremblement repos lèvre/mâchoire
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                 ON_MSDROIT_AMPLI_TREMBL  \
# 0  amplitude tremblement repos MS droit
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                   ON_MSGCHE_AMPLI_TREMBL  \
# 0  amplitude tremblement repos MS gauche
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                 ON_MIDROIT_AMPLI_TREMBL  \
# 0  amplitude tremblement repos MI droit
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                   ON_MIGCHE_AMPLI_TREMBL    ON_CONSTANCE_TREMBL    ON_SS_TOT2  \
# 0  amplitude tremblement repos MI gauche  constance tremblement  sous total 2
# 1                                    NaN                    NaN             0
# 2                                    NaN                    NaN             0
# 3                                    NaN                    NaN             0
# 4                                    NaN                    NaN             0
#
#   ON_TOTAL
# 0    TOTAL
# 1        0
# 2        0
# 3        0
# 4        0
#
# [5 rows x 41 columns]

# %%
df_UPDRSIII_COMPLET_V3_V5["VISIT"].value_counts()
# Out:
# VISIT
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# Visit                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_v3_UPDRSIII_COMPLET = df_v1_2_3[df_v1_2_3["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_UPDRSIII_COMPLET = df_v1_2_3[df_v1_2_3["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### UPDRSIII_TOTAUX

# %% [markdown]
# #### ECMP

# %%
df_ECMP = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="ECMP")
print(df_ECMP.shape)
df_ECMP.head()
# Out:
# (3341, 45)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-001                 SR
#
#                        TITRE       HUMEUR_DEPRE  \
# 0                      titre  humeur dépressive
# 1        Visite de screening                  0
# 2   Visite Bilan à 1 an - V1                NaN
# 3  Visite Bilan à 3 ans - V3                NaN
# 4  Visite Bilan à 5 ans - V5                NaN
#
#                HUMEUR_DEPRE_ATCD  ANXIETE         ANXIETE_ATCD  \
# 0  humeur dépressive antécédents  anxiete  anxiété antécédents
# 1                            OUI        1                  NaN
# 2                            NaN      NaN                  NaN
# 3                            NaN      NaN                  NaN
# 4                            NaN      NaN                  NaN
#
#              IRRITABI_AGRESS                   IRRITABI_AGRESS_ATCD  \
# 0  irritabilité, agressivité  irritabilité, agressivité antécédents
# 1                          1                                    NaN
# 2                        NaN                                    NaN
# 3                        NaN                                    NaN
# 4                        NaN                                    NaN
#
#         HYPEREMOT  ...  ACHATS_COMPULSIFS         ACHATS_COMPULSIFS_ATCD  \
# 0  hyperémotivité  ...  achats compulsifs  achats compulsifs antécédents
# 1               0  ...                  0                            NaN
# 2             NaN  ...                NaN                            NaN
# 3             NaN  ...                NaN                            NaN
# 4             NaN  ...                NaN                            NaN
#
#         JEU_PATHOLQ              JEU_PATHOLQ_ATCD   HYPERSEXUALIT  \
# 0  jeu pathologique  jeu pathologique antécédents  hypersexualité
# 1                 0                           NaN               0
# 2               NaN                           NaN             NaN
# 3               NaN                           NaN             NaN
# 4               NaN                           NaN             NaN
#
#            HYPERSEXUALIT_ATCD            ADDICTION_DOPA  \
# 0  hypersexualité antécédents  addiction dopaminergique
# 1                         OUI                         0
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#                     ADDICTION_DOPA_ATCD  MODE_APPETITIF  \
# 0  addiction dopaminergique antécédents  mode appétitif
# 1                                   NaN               0
# 2                                   NaN             NaN
# 3                                   NaN             NaN
# 4                                   NaN             NaN
#
#           MODE_APPETITIF_ATCD
# 0  mode appétitif antécédents
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 45 columns]

# %%
df_ECMP["TITRE"].value_counts()
# Out:
# TITRE
# Visite de screening          835
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# titre                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_V0_ECMP = df_ECMP[df_ECMP["TITRE"] == "Visite de screening"].reset_index(drop=True)
df_v1_ECMP = df_ECMP[df_ECMP["TITRE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_ECMP = df_ECMP[df_ECMP["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_ECMP = df_ECMP[df_ECMP["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### QUIP

# %%
df_QUIP = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="QUIP ")
print(df_QUIP.shape)
df_QUIP.head()
# Out:
# (3341, 34)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-001                 SR
#
#                        TITRE      RENSEIGNMT  QUIP_A1_JEU  QUIP_A1_SEXE  \
# 0                      titre  renseignements  QUIP_A1_jeu  QUIP_A1_sexe
# 1        Visite de screening               1            0             1
# 2   Visite Bilan à 1 an - V1             NaN          NaN           NaN
# 3  Visite Bilan à 3 ans - V3             NaN          NaN           NaN
# 4  Visite Bilan à 5 ans - V5             NaN          NaN           NaN
#
#    QUIP_A1_ACHATS          QUIP_A1_PULSIONS_ALIM      QUEST2_JEU  \
# 0  QUIP_A1_achats  QUIP_A1_pulsions_alimentaires  question 2 jeu
# 1               0                              0               0
# 2             NaN                            NaN             NaN
# 3             NaN                            NaN             NaN
# 4             NaN                            NaN             NaN
#
#             QUEST2_SEXE  ...                          QUIP_B1A  \
# 0  question 2 sexualité  ...  autres comportemetns question 1a
# 1                     1  ...                                 1
# 2                   NaN  ...                               NaN
# 3                   NaN  ...                               NaN
# 4                   NaN  ...                               NaN
#
#                            QUIP_B1B                          QUIP_B1C  \
# 0  autres comportemetns question 1b  autres comportemetns question 1c
# 1                                 0                                 0
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#                            QUIP_B2                          QUIP_B3  \
# 0  autres comportemetns question 2  autres comportemetns question 3
# 1                                0                                0
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#                             QUIP_C1                           QUIP_C2  \
# 0  usage des médicaments question 1  usage des médicaments question 2
# 1                                 1                                 0
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#                             QUIP_C3                           QUIP_C4  \
# 0  usage des médicaments question 3  usage des médicaments question 4
# 1                                 0                                 0
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#                             QUIP_C5
# 0  usage des médicaments question 5
# 1                                 0
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 34 columns]

# %%
df_QUIP["TITRE"].value_counts()
# Out:
# TITRE
# Visite de screening          835
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# titre                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_V0_QUIP = df_QUIP[df_QUIP["TITRE"] == "Visite de screening"].reset_index(drop=True)
df_v1_QUIP = df_QUIP[df_QUIP["TITRE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_QUIP = df_QUIP[df_QUIP["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_QUIP = df_QUIP[df_QUIP["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### UPPS

# %%
df_UPPS = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="UPPS")
print(df_UPPS.shape)
df_UPPS.head()
# Out:
# (3341, 23)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-001                 SR
#
#                        TITRE  UPPS1  UPPS2  UPPS3  UPPS4  UPPS5  UPPS6  UPPS7  \
# 0                      titre  UPPS1  UPPS2  UPPS3  UPPS4  UPPS5  UPPS6  UPPS7
# 1        Visite de screening      1      2      3      4      1      1      4
# 2   Visite Bilan à 1 an - V1    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  Visite Bilan à 3 ans - V3    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4  Visite Bilan à 5 ans - V5    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    ...  UPPS11  UPPS12  UPPS13  UPPS14  UPPS15  UPPS16  UPPS17  UPPS18  \
# 0  ...  UPPS11  UPPS12  UPPS13  UPPS14  UPPS15  UPPS16  UPPS17  UPPS18
# 1  ...       1       4       1       4       4       1       4       1
# 2  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    UPPS19  UPPS20
# 0  UPPS19  UPPS20
# 1       1       3
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
# [5 rows x 23 columns]

# %%
df_UPPS["TITRE"].value_counts()
# Out:
# TITRE
# Visite de screening          835
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# titre                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_V0_QUIP = df_QUIP[df_QUIP["TITRE"] == "Visite de screening"].reset_index(drop=True)
df_v1_QUIP = df_QUIP[df_QUIP["TITRE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_QUIP = df_QUIP[df_QUIP["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_QUIP = df_QUIP[df_QUIP["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### MOCA_V0_V3

# %%
df_MOCA_V0_V3 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="MOCA_V0_V3")
print(df_MOCA_V0_V3.shape)
df_MOCA_V0_V3.head()
# Out:
# (1671, 15)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-002                 TM
# 4                            01-002                 TM
#
#                        TITRE                        AGEINF12  \
# 0                      titre  Age inférieur ou égal à 12 ans
# 1        Visite de screening                             NaN
# 2  Visite Bilan à 3 ans - V3                             NaN
# 3        Visite de screening                             NaN
# 4  Visite Bilan à 3 ans - V3                             NaN
#
#                    MOCA_VISUO         MOCA_DENOM MOCA_ATTENTION1  \
# 0  MoCA Visuospatial/exécutif  MoCA dénomination  MoCA attention
# 1                         NaN                NaN             NaN
# 2                         NaN                NaN             NaN
# 3                         NaN                NaN             NaN
# 4                         NaN                NaN             NaN
#
#     MOCA_ATTENTION2   MOCA_ATTENTION3 MOCA_LANGAGE1   MOCA_LANGAGE2  \
# 0  MoCA attention 2  MoCA attention 3  MoCA langage  MoCA langage 2
# 1               NaN               NaN           NaN             NaN
# 2               NaN               NaN           NaN             NaN
# 3               NaN               NaN           NaN             NaN
# 4               NaN               NaN           NaN             NaN
#
#         MOCA_ABSTAC  MOCA_RAPPEL  MOCA_ORIENTATION        MOCA_SCORE
# 0  MoCA abstraction  MoCA rappel  MoCA orientation  MoCA score total
# 1               NaN          NaN               NaN               NaN
# 2               NaN          NaN               NaN               NaN
# 3               NaN          NaN               NaN               NaN
# 4               NaN          NaN               NaN               NaN

# %%
df_MOCA_V0_V3["TITRE"].value_counts()
# Out:
# TITRE
# Visite de screening          835
# Visite Bilan à 3 ans - V3    835
# titre                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_V0_MOCA = df_MOCA_V0_V3[df_MOCA_V0_V3["TITRE"] == "Visite de screening"].reset_index(drop=True)
df_v3_MOCA = df_MOCA_V0_V3[df_MOCA_V0_V3["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)

# %% [markdown]
# #### MOCA_V1_V5

# %%
df_MOCA_V1_V5 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="MOCA_V1_V5")
print(df_MOCA_V1_V5.shape)
df_MOCA_V1_V5.head()
# Out:
# (1671, 15)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-002                 TM
# 4                            01-002                 TM
#
#                        TITRE                               SCOLINF12  \
# 0                      titre  Scolarité inférieure ou égale à 12 ans
# 1   Visite Bilan à 1 an - V1                                     NaN
# 2  Visite Bilan à 5 ans - V5                                     NaN
# 3   Visite Bilan à 1 an - V1                                     NaN
# 4  Visite Bilan à 5 ans - V5                                     NaN
#
#                    MOCA_VISUO         MOCA_DENOM   MOCA_ATTENTION1  \
# 0  MoCA visuospatial/éxécutif  MoCA dénomination  MoCA attention 1
# 1                         NaN                NaN               NaN
# 2                         NaN                NaN               NaN
# 3                         NaN                NaN               NaN
# 4                         NaN                NaN               NaN
#
#     MOCA_ATTENTION2   MOCA_ATTENTION3   MOCA_LANGAGE1   MOCA_LANGAGE2  \
# 0  MoCA attention 2  MoCA attention 3  MoCA langage 1  MoCA langage 2
# 1               NaN               NaN             NaN             NaN
# 2               NaN               NaN             NaN             NaN
# 3               NaN               NaN             NaN             NaN
# 4               NaN               NaN             NaN             NaN
#
#         MOCA_ABSTAC  MOCA_RAPPEL  MOCA_ORIENTATION  MOCA_SCORE
# 0  MoCA abstraction  MoCA rappel  MoCA orientation  MoCA score
# 1               NaN          NaN               NaN         NaN
# 2               NaN          NaN               NaN         NaN
# 3               NaN          NaN               NaN         NaN
# 4               NaN          NaN               NaN         NaN

# %%
df_MOCA_V1_V5["TITRE"].value_counts()
# Out:
# TITRE
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 5 ans - V5    835
# titre                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_v1_MOCA = df_MOCA_V1_V5[df_MOCA_V1_V5["TITRE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v5_MOCA = df_MOCA_V1_V5[df_MOCA_V1_V5["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### HAMD

# %%
df_HAMD = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="HAMD")
print(df_HAMD.shape)
df_HAMD.head()
# Out:
# (3341, 23)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-001                 SR
#
#                        TITRE      HAMD_1      HAMD_2      HAMD_3      HAMD_4  \
# 0                       titr  Hamilton 1  Hamilton 2  Hamilton 3  Hamilton 4
# 1        Visite de screening           0           0           0           0
# 2   Visite Bilan à 1 an - V1         NaN         NaN         NaN         NaN
# 3  Visite Bilan à 3 ans - V3         NaN         NaN         NaN         NaN
# 4  Visite Bilan à 5 ans - V5         NaN         NaN         NaN         NaN
#
#        HAMD_5      HAMD_6      HAMD_7  ...      HAMD_11      HAMD_12  \
# 0  Hamilton 5  Hamilton 6  Hamilton 7  ...  Hamilton 11  Hamilton 12
# 1           0           0           1  ...            2            0
# 2         NaN         NaN         NaN  ...          NaN          NaN
# 3         NaN         NaN         NaN  ...          NaN          NaN
# 4         NaN         NaN         NaN  ...          NaN          NaN
#
#        HAMD_13      HAMD_14      HAMD_15      HAMD_16A      HAMD_16B  \
# 0  Hamilton 13  Hamilton 14  Hamilton 15  Hamilton 16A  Hamilton 16B
# 1            0            0            0             0           NaN
# 2          NaN          NaN          NaN           NaN           NaN
# 3          NaN          NaN          NaN           NaN           NaN
# 4          NaN          NaN          NaN           NaN           NaN
#
#        HAMD_17   HAMD_SCORECALC                   DEPRESSION
# 0  Hamilton 17  Hamilton calcul        échelle de dépression
# 1            0                4  Symptomes dépressifs légers
# 2          NaN              NaN                          NaN
# 3          NaN              NaN                          NaN
# 4          NaN              NaN                          NaN
#
# [5 rows x 23 columns]

# %%
df_HAMD["TITRE"].value_counts()
# Out:
# TITRE
# Visite de screening          835
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# titr                           1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_V0_HAMD = df_HAMD[df_HAMD["TITRE"] == "Visite de screening"].reset_index(drop=True)
df_v1_HAMD = df_HAMD[df_HAMD["TITRE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_HAMD = df_HAMD[df_HAMD["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_HAMD = df_HAMD[df_HAMD["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### HAMA

# %%
df_HAMA = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="HAMA ")
print(df_HAMA.shape)
df_HAMA.head()
# Out:
# (3341, 19)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-001                 SR
#
#                        TITRE              HAMA_HUM_ANX      HAMA_TENSION  \
# 0                      titre  Hamilton humeur anxieuse  Hamilton tension
# 1        Visite de screening                     Léger            Absent
# 2   Visite Bilan à 1 an - V1                       NaN               NaN
# 3  Visite Bilan à 3 ans - V3                       NaN               NaN
# 4  Visite Bilan à 5 ans - V5                       NaN               NaN
#
#        HAMA_PEURS        HAMA_INSOMN                      HAMA_FCT_INTEL  \
# 0  Hamilton peurs  Hamilton insomnie  Hamilton fonctions intellectuelles
# 1          Absent             Absent                              Absent
# 2             NaN                NaN                                 NaN
# 3             NaN                NaN                                 NaN
# 4             NaN                NaN                                 NaN
#
#               HAMA_HUM_AGRESS  \
# 0  Hamilton humeur dépressive
# 1                      Absent
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                          HAMA_MUSCUL  \
# 0  Hamilton symptomes somatiques généraux muscula...
# 1                                             Absent
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         HAMA_SENSOR  \
# 0  Hamilton symptomes somaiques généraux sensoriels
# 1                                            Absent
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#                            HAMA_SYMPTCV                  HAMA_SYMPT_RESPI  \
# 0  Hamilton symptomes cardio-vasculaire  Hamilton symtpomes respiratoires
# 1                                Absent                            Modéré
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
#
#                        HAMA_SYMPT_GASTRO                         HAMA_GENITO  \
# 0  Hamilton symptomes gastro-intestinaux  Hamilton symptomes génito-urinaire
# 1                                 Absent                              Absent
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
#
#                             HAMA_SNA  \
# 0  Hamilton système nerveux autonome
# 1                             Absent
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#                       HAMA_COMPORT_ENTRETIEN   HAMA_SCORECALC  \
# 0  Hamilton comportemetn pendant l'entretien  Hamilton calcul
# 1                                     Absent                3
# 2                                        NaN              NaN
# 3                                        NaN              NaN
# 4                                        NaN              NaN
#
#                    ANXIETE
# 0  évaluation de l'anxiété
# 1           Anxiété légère
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df_HAMA["TITRE"].value_counts()
# Out:
# TITRE
# Visite de screening          835
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# titre                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_V0_HAMA = df_HAMA[df_HAMA["TITRE"] == "Visite de screening"].reset_index(drop=True)
df_v1_HAMA = df_HAMA[df_HAMA["TITRE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_HAMA = df_HAMA[df_HAMA["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_HAMA = df_HAMA[df_HAMA["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### LARS

# %%
df_LARS = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="LARS ")
print(df_LARS.shape)
df_LARS.head()
# Out:
# (3341, 14)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-001                 SR
#
#                        TITRE                               LARS_EP  \
# 0                      titre  LARS activités de la vie quotidienne
# 1        Visite de screening                                    -4
# 2   Visite Bilan à 1 an - V1                                   NaN
# 3  Visite Bilan à 3 ans - V3                                   NaN
# 4  Visite Bilan à 5 ans - V5                                   NaN
#
#                   LARS_INT                  LARS_INI  \
# 0  LARS centres d'intérets  LARS prises d'initiative
# 1                        0                        -4
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
#                           LARS_NS                                 LARS_M  \
# 0  LARS intéret pour la nouveauté  LARS motivation - efforts volontaires
# 1                              -4                                     -4
# 2                             NaN                                    NaN
# 3                             NaN                                    NaN
# 4                             NaN                                    NaN
#
#                        LARS_ER           LARS_C           LARS_SL  \
# 0  LARS intensité des émotions  LARS inquiétude  LARS vie sociale
# 1                           -4               -4                -3
# 2                          NaN              NaN               NaN
# 3                          NaN              NaN               NaN
# 4                          NaN              NaN               NaN
#
#                          LARS_SA  LARS_SCORE         LARS_RESULTAT
# 0  LARS capacité d'auto-critique  LARS score  Score LARS résultats
# 1                             -4         -31         Non apathique
# 2                            NaN         NaN                   NaN
# 3                            NaN         NaN                   NaN
# 4                            NaN         NaN                   NaN

# %%
df_LARS["TITRE"].value_counts()
# Out:
# TITRE
# Visite de screening          835
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# titre                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne TITRE
df_V0_LARS = df_LARS[df_LARS["TITRE"] == "Visite de screening"].reset_index(drop=True)
df_v1_LARS = df_LARS[df_LARS["TITRE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_LARS = df_LARS[df_LARS["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_LARS = df_LARS[df_LARS["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### PDQ39

# %%
df_PDQ39 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="PDQ39")
print(df_PDQ39.shape)
df_PDQ39.head()
# Out:
# (3341, 45)
#                              SUBJID                      VISIT  \
# 0  Subject Identifier for the Study                      Visit
# 1                            01-001        Visite de screening
# 2                            01-001   Visite Bilan à 1 an - V1
# 3                            01-001  Visite Bilan à 3 ans - V3
# 4                            01-001  Visite Bilan à 5 ans - V5
#
#             INIT_PAT  SITUATION_MARITALE   PDQ39_1  PDQ39_2  PDQ39_3  \
# 0  initiales patient  situation maritale   PDQ39-1  PDQ39-2  PDQ39-3
# 1                 SR                 Oui  Rarement   Jamais  Parfois
# 2                 SR                 NaN       NaN      NaN      NaN
# 3                 SR                 NaN       NaN      NaN      NaN
# 4                 SR                 NaN       NaN      NaN      NaN
#
#                             PDQ39_4  PDQ39_5   PDQ39_6  ...  PDQ39_32  \
# 0                           PDQ39-4  PDQ39-5   PDQ39-6  ...  PDQ39_32
# 1  Toujours ou ne peut jamais faire  Parfois  Rarement  ...  Rarement
# 2                               NaN      NaN       NaN  ...       NaN
# 3                               NaN      NaN       NaN  ...       NaN
# 4                               NaN      NaN       NaN  ...       NaN
#
#    PDQ39_33  PDQ39_34                   REF_SITU_FAM  PDQ39_35  PDQ39_36  \
# 0  PDQ39_33  PDQ39_34  référence situation familiale  PDQ39_35  PDQ39_36
# 1    Jamais   Parfois                              1  Rarement  Rarement
# 2       NaN       NaN                            NaN       NaN       NaN
# 3       NaN       NaN                            NaN       NaN       NaN
# 4       NaN       NaN                            NaN       NaN       NaN
#
#    PDQ39_37  PDQ39_38  PDQ39_39  PDQ39_SCORE
# 0  PDQ39_37  PDQ39_38  PDQ39_39  score PDQ39
# 1   Parfois   Parfois  Rarement           50
# 2       NaN       NaN       NaN          NaN
# 3       NaN       NaN       NaN          NaN
# 4       NaN       NaN       NaN          NaN
#
# [5 rows x 45 columns]

# %%
df_PDQ39["VISIT"].value_counts()
# Out:
# VISIT
# Visite de screening          835
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# Visit                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne VISIT
df_V0_PDQ39 = df_PDQ39[df_PDQ39["VISIT"] == "Visite de screening"].reset_index(drop=True)
df_v1_PDQ39 = df_PDQ39[df_PDQ39["VISIT"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_PDQ39 = df_PDQ39[df_PDQ39["VISIT"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_PDQ39 = df_PDQ39[df_PDQ39["VISIT"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### DIGITSMT_TRAILMT_DKEFS

# %%
df_DIGITSMT_TRAILMT_DKEFS = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="DIGITSMT_TRAILMT_DKEFS")
print(df_DIGITSMT_TRAILMT_DKEFS.shape)
df_DIGITSMT_TRAILMT_DKEFS.head()
# Out:
# (3341, 22)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-001                 SR
#
#                        TITRE  \
# 0                      titre
# 1        Visite de screening
# 2   Visite Bilan à 1 an - V1
# 3  Visite Bilan à 3 ans - V3
# 4  Visite Bilan à 5 ans - V5
#
#                                    DIGITSMT_NBSUBSTI  \
# 0  Digit Symbol Modalities Test nombre total de s...
# 1                                                 38
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                   DIGITSMT_NBCORRECT  \
# 0  Digit Symbol Modalities Test nombre de substit...
# 1                                                 37
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                               TRAILMT_ALPHABET  \
# 0  récitation de l'alphabet, temps en secondes
# 1                                           .D
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#                          TRAILMT_CHIFFRE  \
# 0  comptage de 1 à 26, temps en secondes
# 1                                     .D
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                            TRAILMT_LETTRECHIFFRE  \
# 0  alternance lettres/nombres, temps en secondes
# 1                                             .D
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#                     TRAILMT_NB_ERREURS              DKEFS_TPS1  ...  \
# 0  alternance lettres/nombres, erreurs  DK-EFS partie 1, temps  ...
# 1                                   .D                      .D  ...
# 2                                  NaN                     NaN  ...
# 3                                  NaN                     NaN  ...
# 4                                  NaN                     NaN  ...
#
#                DKEFS_TPS2                       DKEFS_NBERR2  \
# 0  DK-EFS partie 2, temps  DK-EFS partie 2, nombre d'erreurs
# 1                      .D                                 .D
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
#
#                               DKEFS_AUTOCORR2              DKEFS_TPS3  \
# 0  DK-EFS partie 2, nombre d'auto-corrections  DK-EFS partie 3, temps
# 1                                          .D                      .D
# 2                                         NaN                     NaN
# 3                                         NaN                     NaN
# 4                                         NaN                     NaN
#
#                         DKEFS_NBERR3  \
# 0  DK-EFS partie 3, nombre d'erreurs
# 1                                 .D
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#                               DKEFS_AUTOCORR3              DKEFS_TPS4  \
# 0  DK-EFS partie 3, nombre d'auto-corrections  DK-EFS partie 4, temps
# 1                                          .D                      .D
# 2                                         NaN                     NaN
# 3                                         NaN                     NaN
# 4                                         NaN                     NaN
#
#                         DKEFS_NBERR4  \
# 0  DK-EFS partie 4, nombre d'erreurs
# 1                                 .D
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#                               DKEFS_AUTOCORR4  \
# 0  DK-EFS partie 4, nombre d'auto-corrections
# 1                                          .D
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                        BENTON_NBCORR
# 0  Benton Judgement of Line Orientation test, nom...
# 1                                                 10
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 22 columns]

# %%
df_DIGITSMT_TRAILMT_DKEFS["TITRE"].value_counts()
# Out:
# TITRE
# Visite de screening          835
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# titre                          1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne VISIT
df_V0_DIGITSMT_TRAILMT_DKEFS = df_DIGITSMT_TRAILMT_DKEFS[df_DIGITSMT_TRAILMT_DKEFS["TITRE"] == "Visite de screening"].reset_index(drop=True)
df_v1_DIGITSMT_TRAILMT_DKEFS = df_DIGITSMT_TRAILMT_DKEFS[df_DIGITSMT_TRAILMT_DKEFS["TITRE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_DIGITSMT_TRAILMT_DKEFS = df_DIGITSMT_TRAILMT_DKEFS[df_DIGITSMT_TRAILMT_DKEFS["TITRE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_DIGITSMT_TRAILMT_DKEFS = df_DIGITSMT_TRAILMT_DKEFS[df_DIGITSMT_TRAILMT_DKEFS["TITRE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### CONSO_SPECIFIQUE

# %%
df_CONSO_SPECIFIQUE = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="CONSO_SPECIFIQUE ")
print(df_CONSO_SPECIFIQUE.shape)
df_CONSO_SPECIFIQUE.head()
# Out:
# (4176, 113)
#                              SUBJID  \
# 0  Subject Identifier for the Study
# 1                            01-001
# 2                            01-001
# 3                            01-001
# 4                            01-001
#
#                                                VISIT  NUM  VISIT_NOM  \
# 0                                              Visit  Num  VISIT_NOM
# 1  Traitements concomittants antiparkinsoniens sp...    1  Screening
# 2  Traitements concomittants antiparkinsoniens sp...    2    Post op
# 3  Traitements concomittants antiparkinsoniens sp...    3         V1
# 4  Traitements concomittants antiparkinsoniens sp...    4         V3
#
#       NUM_CENTRE         NUM_PAT           INIT_PAT      MEDICMT1  \
# 0  numéro centre  numéro patient  initiales patient  médicament 1
# 1             01             001                 SR           NaN
# 2             01             001                 SR           NaN
# 3             01             001                 SR           NaN
# 4             01             001                 SR           NaN
#
#           POSO1                       CAT_TRT_ANTIPARK1  ...         CONCAT_4  \
# 0   posologie 1  catégorie traitement antipakinsonien 1  ...  concaténation 4
# 1  200 MG LDOPA                                     NaN  ...                0
# 2           NaN                                     NaN  ...              NaN
# 3           NaN                                     NaN  ...              NaN
# 4           NaN                                     NaN  ...              NaN
#
#           CONCAT_5         CONCAT_6         CONCAT_7         CONCAT_8  \
# 0  concaténation 5  concaténation 6  concaténation 7  concaténation 8
# 1                0                0              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#           CONCAT_9         CONCAT_10         CONCAT_11         CONCAT_12  \
# 0  concaténation 9  concaténation 10  concaténation 11  concaténation 12
# 1              NaN               NaN               NaN               NaN
# 2              NaN               NaN               NaN               NaN
# 3              NaN               NaN               NaN               NaN
# 4              NaN               NaN               NaN               NaN
#
#           CONCAT_13
# 0  concaténation 13
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 113 columns]

# %%
df_CONSO_SPECIFIQUE["NUM"].value_counts()
# Out:
# NUM
# 1      835
# 2      835
# 3      835
# 4      835
# 5      835
# Num      1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne VISIT
df_V0_CONSO_SPECIFIQUE = df_CONSO_SPECIFIQUE[df_CONSO_SPECIFIQUE["NUM"] == "1"].reset_index(drop=True)
df_vc_CONSO_SPECIFIQUE = df_CONSO_SPECIFIQUE[df_CONSO_SPECIFIQUE["NUM"] == "2"].reset_index(drop=True)
df_v1_CONSO_SPECIFIQUE = df_CONSO_SPECIFIQUE[df_CONSO_SPECIFIQUE["NUM"] == "3"].reset_index(drop=True)
df_v3_CONSO_SPECIFIQUE = df_CONSO_SPECIFIQUE[df_CONSO_SPECIFIQUE["NUM"] == "4"].reset_index(drop=True)
df_v5_CONSO_SPECIFIQUE = df_CONSO_SPECIFIQUE[df_CONSO_SPECIFIQUE["NUM"] == "5"].reset_index(drop=True)

# %% [markdown]
# #### Feuil4

# %%
df_Feuil4 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="Feuil4")
print(df_Feuil4.shape)
df_Feuil4.head()
# Out:
# (807, 7)
#              Unnamed: 0              Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                   NaN                     NaN         NaN         NaN
# 1            Somme de v  Étiquettes de colonnes         NaN         NaN
# 2  Étiquettes de lignes                       1         2.0         3.0
# 3                01-001                       1         NaN         NaN
# 4                01-002                       1         NaN         NaN
#
#    Unnamed: 4  Unnamed: 5     Unnamed: 6
# 0         NaN         NaN            NaN
# 1         NaN         NaN            NaN
# 2         4.0         5.0  Total général
# 3         NaN         NaN              1
# 4         NaN         NaN              1

# %% [markdown]
# #### LEDD

# %%
df_LEDD = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="LEDD")
print(df_LEDD.shape)
df_LEDD.head()
# Out:
# (2395, 37)
#    v Subject Identifier for the Study  \
# 0  1                           01-001
# 1  1                           01-002
# 2  1                           01-003
# 3  1                           01-004
# 4  1                           01-004
#
#                                                Visit  Num  \
# 0  Traitements concomittants antiparkinsoniens sp...    1
# 1  Traitements concomittants antiparkinsoniens sp...    1
# 2  Traitements concomittants antiparkinsoniens sp...    1
# 3  Traitements concomittants antiparkinsoniens sp...    1
# 4  Traitements concomittants antiparkinsoniens sp...    2
#
#               médicament 1          posologie 1         médicament 2  \
# 0                      NaN         200 MG LDOPA       MODOPAR 125 LP
# 1                   REQUIP  LP 24 MG 1 PAR JOUR              AZILECT
# 2              STALEVO 200             4 / JOUR          STALEVO 150
# 3  MODOPAR 125 DISPERSIBLE        3 CP LE MATIN  MODOPAR 125 GELULES
# 4            ROPINIROLE LP                  6MG           SINEMET LP
#
#      posologie 2    médicament 3             posologie 3  ... posologie 12  \
# 0  100 MG L DOPA   STALEVO 75 MG     5X75= 250 MG L DOPA  ...          NaN
# 1  1 MG LE MATIN         MODOPAR  125 MG LP 2 AU COUCHER  ...          NaN
# 2       3 / JOUR         AZILECT                     1MG  ...          NaN
# 3     7 PAR JOUR  SINEMET LP 100               2 LE SOIR  ...          NaN
# 4          200MG     MODOPAR 125                   300MG  ...          NaN
#
#   médicament 13 posologie 13 ledd_levo fact_icomt ledd_levot ledd_agot  \
# 0           NaN          NaN     550.0       1.33      731.5     240.0
# 1           NaN          NaN    1300.0       1.33     1729.0     480.0
# 2           NaN          NaN    1350.0       1.33     1795.5       NaN
# 3           NaN          NaN    1150.0       1.00     1150.0     480.0
# 4           NaN          NaN     700.0       1.00      700.0     120.0
#
#   ledd_imaobt ledd_mantt ledd_tot
# 0         NaN      400.0   1371.5
# 1       100.0        NaN   2309.0
# 2       100.0        NaN   1895.5
# 3         NaN        NaN   1630.0
# 4         NaN        NaN    820.0
#
# [5 rows x 37 columns]

# %%
df_LEDD["Num"].value_counts()
# Out:
# Num
# 1    794
# 3    525
# 2    491
# 5    313
# 4    272
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne VISIT
df_V0_LEDD = df_LEDD[df_LEDD["Num"] == 1].reset_index(drop=True)
df_vc_LEDD = df_LEDD[df_LEDD["Num"] == 2].reset_index(drop=True)
df_v1_LEDD = df_LEDD[df_LEDD["Num"] == 3].reset_index(drop=True)
df_v3_LEDD = df_LEDD[df_LEDD["Num"] == 4].reset_index(drop=True)
df_v5_LEDD = df_LEDD[df_LEDD["Num"] == 5].reset_index(drop=True)

# %% [markdown]
# #### Feuil1

# %%
df_Feuil1 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="Feuil1")
print(df_Feuil1.shape)
df_Feuil1.head()
# Out:
# (2395, 7)
#   Subject Identifier for the Study  Num  ledd_levot  ledd_agot  ledd_imaobt  \
# 0                           01-001    1       731.5      240.0          NaN
# 1                           01-002    1      1729.0      480.0        100.0
# 2                           01-003    1      1795.5        NaN        100.0
# 3                           01-004    1      1150.0      480.0          NaN
# 4                           01-004    2       700.0      120.0          NaN
#
#    ledd_mantt  ledd_tot
# 0       400.0    1371.5
# 1         NaN    2309.0
# 2         NaN    1895.5
# 3         NaN    1630.0
# 4         NaN     820.0

# %%
df_Feuil1["Num"].value_counts()
# Out:
# Num
# 1    794
# 3    525
# 2    491
# 5    313
# 4    272
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne VISIT
df_V0_Feuil1 = df_Feuil1[df_Feuil1["Num"] == 1].reset_index(drop=True)
df_vc_Feuil1 = df_Feuil1[df_Feuil1["Num"] == 2].reset_index(drop=True)
df_v1_Feuil1 = df_Feuil1[df_Feuil1["Num"] == 3].reset_index(drop=True)
df_v3_Feuil1 = df_Feuil1[df_Feuil1["Num"] == 4].reset_index(drop=True)
df_v5_Feuil1 = df_Feuil1[df_Feuil1["Num"] == 5].reset_index(drop=True)

# %% [markdown]
# #### Feuil2

# %%
df_Feuil2 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="Feuil2")
print(df_Feuil2.shape)
df_Feuil2.head()
# Out:
# (834, 10)
#   Subject Identifier for the Study  Num  ledd_levot  ledd_agot  ledd_imaobt  \
# 0                           01-001  NaN         NaN        NaN          NaN
# 1                           01-002  NaN         NaN        NaN          NaN
# 2                           01-003  NaN         NaN        NaN          NaN
# 3                           01-004  NaN         NaN        NaN          NaN
# 4                           01-005  NaN         NaN        NaN          NaN
#
#    ledd_mantt  ledd_tot  Unnamed: 7  Unnamed: 8  01-001
# 0         NaN       NaN         NaN         NaN  01-002
# 1         NaN       NaN         NaN         NaN  01-003
# 2         NaN       NaN         NaN         NaN  01-004
# 3         NaN       NaN         NaN         NaN  01-005
# 4         NaN       NaN         NaN         NaN  01-006

# %% [markdown]
# #### PSYCHOTROPES

# %%
df_PSYCHOTROPES = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="PSYCHOTROPES")
print(df_PSYCHOTROPES.shape)
df_PSYCHOTROPES.head()
# Out:
# (4176, 83)
#                              SUBJID                         VISIT  NUM  \
# 0  Subject Identifier for the Study                         Visit  Num
# 1                            01-001  Les traitements psychotropes    1
# 2                            01-001  Les traitements psychotropes    2
# 3                            01-001  Les traitements psychotropes    3
# 4                            01-001  Les traitements psychotropes    4
#
#   Unnamed: 3           INIT_PAT      MEDICMT1           D_DEB1        POSO1  \
# 0        NaN  initiales patient  médicament 1  date de début 1  posologie 1
# 1         V0                 SR           NaN              NaN          NaN
# 2         Vc                 SR           NaN              NaN          NaN
# 3         V1                 SR           NaN              NaN          NaN
# 4         V3                 SR           NaN              NaN          NaN
#
#          INDIC1         D_FIN1  ...        POSO12        INDIC12  \
# 0  indication 1  date de fin 1  ...  posologie 12  indication 12
# 1           NaN            NaN  ...           NaN            NaN
# 2           NaN            NaN  ...           NaN            NaN
# 3           NaN            NaN  ...           NaN            NaN
# 4           NaN            NaN  ...           NaN            NaN
#
#           D_FIN12    ENCOURS12      MEDICMT13           D_DEB13        POSO13  \
# 0  date de fin 12  en cours 12  médicament 13  date de début 13  posologie 13
# 1             NaN          NaN            NaN               NaN           NaN
# 2             NaN          NaN            NaN               NaN           NaN
# 3             NaN          NaN            NaN               NaN           NaN
# 4             NaN          NaN            NaN               NaN           NaN
#
#          INDIC13         D_FIN13    ENCOURS13
# 0  indication 13  date de fin 13  en cours 13
# 1            NaN             NaN          NaN
# 2            NaN             NaN          NaN
# 3            NaN             NaN          NaN
# 4            NaN             NaN          NaN
#
# [5 rows x 83 columns]

# %%
df_PSYCHOTROPES["NUM"].value_counts()
# Out:
# NUM
# 1      835
# 2      835
# 3      835
# 4      835
# 5      835
# Num      1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne VISIT
df_V0_PSYCHOTROPES = df_PSYCHOTROPES[df_PSYCHOTROPES["NUM"] == "1"].reset_index(drop=True)
df_vc_PSYCHOTROPES = df_PSYCHOTROPES[df_PSYCHOTROPES["NUM"] == "2"].reset_index(drop=True)
df_v1_PSYCHOTROPES = df_PSYCHOTROPES[df_PSYCHOTROPES["NUM"] == "3"].reset_index(drop=True)
df_v3_PSYCHOTROPES = df_PSYCHOTROPES[df_PSYCHOTROPES["NUM"] == "4"].reset_index(drop=True)
df_v5_PSYCHOTROPES = df_PSYCHOTROPES[df_PSYCHOTROPES["NUM"] == "5"].reset_index(drop=True)

# %% [markdown]
# #### AUTRE_PARKINSON

# %%
df_AUTRE_PARKINSON = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="AUTRE_PARKINSON")
print(df_AUTRE_PARKINSON.shape)
df_AUTRE_PARKINSON.head()
# Out:
# (4176, 83)
#                              SUBJID  \
# 0  Subject Identifier for the Study
# 1                            01-001
# 2                            01-001
# 3                            01-001
# 4                            01-001
#
#                                                VISIT  NUM Unnamed: 3  \
# 0                                              Visit  Num        NaN
# 1  Autres médicaments prescrits dans le cadre de ...    1         V0
# 2  Autres médicaments prescrits dans le cadre de ...    2         Vc
# 3  Autres médicaments prescrits dans le cadre de ...    3         V1
# 4  Autres médicaments prescrits dans le cadre de ...    4         V3
#
#             INIT_PAT      MEDICMT1           D_DEB1        POSO1  \
# 0  initiales patient  médicament 1  date de début 1  posologie 1
# 1                 SR           NaN              NaN          NaN
# 2                 SR           NaN              NaN          NaN
# 3                 SR           NaN              NaN          NaN
# 4                 SR           NaN              NaN          NaN
#
#          INDIC1         D_FIN1  ...        POSO12        INDIC12  \
# 0  indication 1  date de fin 1  ...  posologie 12  indication 12
# 1           NaN            NaN  ...           NaN            NaN
# 2           NaN            NaN  ...           NaN            NaN
# 3           NaN            NaN  ...           NaN            NaN
# 4           NaN            NaN  ...           NaN            NaN
#
#           D_FIN12    ENCOURS12      MEDICMT13           D_DEB13        POSO13  \
# 0  date de fin 12  en cours 12  médicament 13  date de début 13  posologie 13
# 1             NaN          NaN            NaN               NaN           NaN
# 2             NaN          NaN            NaN               NaN           NaN
# 3             NaN          NaN            NaN               NaN           NaN
# 4             NaN          NaN            NaN               NaN           NaN
#
#          INDIC13         D_FIN13    ENCOURS13
# 0  indication 13  date de fin 13  en cours 13
# 1            NaN             NaN          NaN
# 2            NaN             NaN          NaN
# 3            NaN             NaN          NaN
# 4            NaN             NaN          NaN
#
# [5 rows x 83 columns]

# %%
df_AUTRE_PARKINSON["NUM"].value_counts()
# Out:
# NUM
# 1      835
# 2      835
# 3      835
# 4      835
# 5      835
# Num      1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne VISIT
df_V0_AUTRE_PARKINSON = df_AUTRE_PARKINSON[df_AUTRE_PARKINSON["NUM"] == "1"].reset_index(drop=True)
df_vc_AUTRE_PARKINSON = df_AUTRE_PARKINSON[df_AUTRE_PARKINSON["NUM"] == "2"].reset_index(drop=True)
df_v1_AUTRE_PARKINSON = df_AUTRE_PARKINSON[df_AUTRE_PARKINSON["NUM"] == "3"].reset_index(drop=True)
df_v3_AUTRE_PARKINSON = df_AUTRE_PARKINSON[df_AUTRE_PARKINSON["NUM"] == "4"].reset_index(drop=True)
df_v5_AUTRE_PARKINSON = df_AUTRE_PARKINSON[df_AUTRE_PARKINSON["NUM"] == "5"].reset_index(drop=True)

# %% [markdown]
# #### FREQUENCE_V1_3_5

# %%
df_FREQUENCE_V1_3_5 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="FREQUENCE_V1_3_5 ")
print(df_FREQUENCE_V1_3_5.shape)
df_FREQUENCE_V1_3_5.head()
# Out:
# (2506, 123)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-002                 TM
#
#                       VISITE         PLOTG1  AMPLITUDEG1  UNITEG1  DUREEG1  \
# 0                     visite  plot gauche 1  amplitude 1  unité 1  durée 1
# 1   Visite Bilan à 1 an - V1            NaN          NaN      NaN      NaN
# 2  Visite Bilan à 3 ans - V3            NaN          NaN      NaN      NaN
# 3  Visite Bilan à 5 ans - V5            NaN          NaN      NaN      NaN
# 4   Visite Bilan à 1 an - V1            NaN          NaN      NaN      NaN
#
#    FREQUENCEG1  IMPEDANCEG1         PLOTG2  ...         NVUNITED4  \
# 0  fréquence 1  impédance 1  plot gauche 2  ...  nouveau unité D4
# 1          NaN          NaN            NaN  ...               NaN
# 2          NaN          NaN            NaN  ...               NaN
# 3          NaN          NaN            NaN  ...               NaN
# 4          NaN          NaN            NaN  ...               NaN
#
#           NVDUREED4         NVFREQUENCED4         NVIMPEDANCED4  \
# 0  nouveau durée D4  nouveau fréquence D4  nouveau impédance D4
# 1               NaN                   NaN                   NaN
# 2               NaN                   NaN                   NaN
# 3               NaN                   NaN                   NaN
# 4               NaN                   NaN                   NaN
#
#                 NVPLOTD5          NVAMPLITUED5         NVUNITED5  \
# 0  nouveau plot droite 5  nouveau amplitude D5  nouveau unité D5
# 1                    NaN                   NaN               NaN
# 2                    NaN                   NaN               NaN
# 3                    NaN                   NaN               NaN
# 4                    NaN                   NaN               NaN
#
#           NVDUREED5         NVFREQUENCED5         NVIMPEDANCED5
# 0  nouveau durée D5  nouveau fréquence D5  nouveau impédance D5
# 1               NaN                   NaN                   NaN
# 2               NaN                   NaN                   NaN
# 3               NaN                   NaN                   NaN
# 4               NaN                   NaN                   NaN
#
# [5 rows x 123 columns]

# %%
df_FREQUENCE_V1_3_5["VISITE"].value_counts()
# Out:
# VISITE
# Visite Bilan à 1 an - V1     835
# Visite Bilan à 3 ans - V3    835
# Visite Bilan à 5 ans - V5    835
# visite                         1
# Name: count, dtype: int64

# %%
# Séparer le dataset par valeur de la colonne VISITE
df_v1_FREQUENCE = df_FREQUENCE_V1_3_5[df_FREQUENCE_V1_3_5["VISITE"] == "Visite Bilan à 1 an - V1"].reset_index(drop=True)
df_v3_FREQUENCE = df_FREQUENCE_V1_3_5[df_FREQUENCE_V1_3_5["VISITE"] == "Visite Bilan à 3 ans - V3"].reset_index(drop=True)
df_v5_FREQUENCE = df_FREQUENCE_V1_3_5[df_FREQUENCE_V1_3_5["VISITE"] == "Visite Bilan à 5 ans - V5"].reset_index(drop=True)

# %% [markdown]
# #### DATES_VISITE

# %%
df_DATES_VISITE = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="DATES_VISITE")
print(df_DATES_VISITE.shape)
df_DATES_VISITE.head()
# Out:
# (836, 6)
#                              SUBJID                        D_SCREEN  \
# 0  Subject Identifier for the Study  date de la visite de screening
# 1                            01-001                      18/11/2013
# 2                            01-002                      13/01/2014
# 3                            01-003                      04/03/2014
# 4                            01-004                      12/05/2014
#
#                                    D_CHIR               DATE_V1  \
# 0  date de l'intervention de la chirurgie  Date de la visite V1
# 1                                     NaN                   NaN
# 2                                     NaN                   NaN
# 3                                     NaN                   NaN
# 4                              23/09/2014                   NaN
#
#                 DATE_V3               DATE_V5
# 0  Date de la visite V3  Date de la visite V5
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN

# %%
df_V0_DATES_VISITE = df_DATES_VISITE[["SUBJID","D_SCREEN"]]
df_vc_DATES_VISITE = df_DATES_VISITE[["SUBJID","D_CHIR"]]
df_v1_DATES_VISITE = df_DATES_VISITE[["SUBJID","DATE_V1"]]
df_v3_DATES_VISITE = df_DATES_VISITE[["SUBJID","DATE_V3"]]
df_v5_DATES_VISITE = df_DATES_VISITE[["SUBJID","DATE_V5"]]

# %% [markdown]
# #### FIN_ETUDE

# %%
df_FIN_ETUDEQUIP = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="FIN_ETUDE")
print(df_FIN_ETUDEQUIP.shape)
df_FIN_ETUDEQUIP.head()
# Out:
# (836, 9)
#                              SUBJID  SUIVI_ETUDE             D_FIN_ETUDE  \
# 0  Subject Identifier for the Study  suivi étude  date de fin de l'étude
# 1                            01-001            0                     NaN
# 2                            01-002            0                     NaN
# 3                            01-003            0                     NaN
# 4                            01-004            0                     NaN
#
#               D_SORTIE_PREMA          MOTIF_SORTIE_PREMA  \
# 0  date de sortie prématurée  motif de sortie prématurée
# 1                 22/11/2013                           1
# 2                 20/02/2014                           6
# 3                 07/03/2014                           1
# 4                 09/01/2015                           6
#
#                                      AUTRE_PRECIS  \
# 0                                 autre précision
# 1                                             NaN
# 2                  SUSPICION DE CANCER PULMONAIRE
# 3                                             NaN
# 4  RETRAIT DU MATERIEL ET RETRAIT DE CONSENTEMENT
#
#                         D_INVESTIGATEUR       NOM_INVESTIGATEUR  \
# 0  date de signature de l'investigateur  nom de l'investigateur
# 1                            18/03/2014         MOREAU CAROLINE
# 2                            24/03/2014               DR MOREAU
# 3                            21/03/2014          DR HOPES LUCIE
# 4                            09/01/2015                   DEVOS
#
#               MOTIF_SORTIE_PREMA1
# 0  motif de sortie prématurée LIB
# 1               Patient non opéré
# 2                           Autre
# 3               Patient non opéré
# 4                           Autre

# %%
import pandas as pd

with pd.ExcelWriter("Output/info_statiques.xlsx", mode="a", engine="openpyxl") as writer:
    df_FIN_ETUDEQUIP.to_excel(writer, sheet_name="Sheet2", index=False)

# %% [markdown]
# #### Fichier Excel

# %%
df_v3
# Out:
#      SUBJID INIT_PAT                      TITRE        DATE POIDS POIDS_NR  \
# 0    01-001       SR  Visite Bilan à 3 ans - V3         NaN   NaN      NaN
# 1    01-002       TM  Visite Bilan à 3 ans - V3         NaN   NaN      NaN
# 2    01-003       SJ  Visite Bilan à 3 ans - V3         NaN   NaN      NaN
# 3    01-004       DJ  Visite Bilan à 3 ans - V3         NaN   NaN      NaN
# 4    01-005       LB  Visite Bilan à 3 ans - V3  17/04/2018   NaN        1
# ..      ...      ...                        ...         ...   ...      ...
# 830  20-025       DA  Visite Bilan à 3 ans - V3         NaN   NaN      NaN
# 831  20-026       ME  Visite Bilan à 3 ans - V3  20/07/2022   121      NaN
# 832  20-027       RP  Visite Bilan à 3 ans - V3         NaN   NaN      NaN
# 833  20-028       DN  Visite Bilan à 3 ans - V3         NaN   NaN      NaN
# 834  20-029       DA  Visite Bilan à 3 ans - V3         NaN   NaN      NaN
#
#     TAILLE TAILLE_NR
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      169       NaN
# ..     ...       ...
# 830    NaN       NaN
# 831    187       NaN
# 832    NaN       NaN
# 833    NaN       NaN
# 834    NaN       NaN
#
# [835 rows x 8 columns]

# %%
import pandas as pd

lis = [name for name, val in globals().items() 
 if isinstance(val, pd.DataFrame) and name.startswith("df_v5")]
display(lis)
print(len(lis))
# Out:
# ['df_v5',
#  'df_v5_Feuil1',
#  'df_v5_LEDD',
#  'df_v5_PSYCHOTROPES',
#  'df_v5_AUTRE_PARKINSON',
#  'df_v5_FREQUENCE',
#  'df_v5_CONSO_SPECIFIQUE',
#  'df_v5_DIGITSMT_TRAILMT_DKEFS',
#  'df_v5_PDQ39',
#  'df_v5_LARS',
#  'df_v5_HAMA',
#  'df_v5_HAMD',
#  'df_v5_MOCA',
#  'df_v5_QUIP',
#  'df_v5_ECMP',
#  'df_v5_UPDRSIII_COMPLET',
#  'df_v5_UPDRS',
#  'df_v5_Poids_Taille',
#  'df_v5_DATES_VISITE']
# 19

# %%
import pandas as pd

# ============================================================
#   DOSSIER DE SORTIE  (change si besoin)
# ============================================================
OUTPUT_DIR = "Output"   


# ============================================================
#   GROUPE 1 : fichier V0.xlsx
# ============================================================
sheets_V0 = {
    "DATES_VISITE"                 : df_V0_DATES_VISITE,
    "df_V0"                        : df_V0,
    "Feuil1"                       : df_V0_Feuil1,
    "LEDD"                         : df_V0_LEDD,
    "PSYCHOTROPES"                 : df_V0_PSYCHOTROPES,
    "AUTRE_PARKINSON"              : df_V0_AUTRE_PARKINSON,
    "CONSO_SPECIFIQUE"             : df_V0_CONSO_SPECIFIQUE,
    "DIGITSMT_TRAILMT_DKEFS"       : df_V0_DIGITSMT_TRAILMT_DKEFS,
    "PDQ39"                        : df_V0_PDQ39,
    "LARS"                         : df_V0_LARS,
    "HAMA"                         : df_V0_HAMA,
    "HAMD"                         : df_V0_HAMD,
    "MOCA"                         : df_V0_MOCA,
    "QUIP"                         : df_V0_QUIP,
    "ECMP"                         : df_V0_ECMP,
    "UPDRS"                        : df_V0_UPDRS,
    
}

# ============================================================
#   GROUPE 2 : fichier v1.xlsx
# ============================================================
sheets_v1 = {
    "DATES_VISITE"                 : df_v1_DATES_VISITE,
    "df_v1"                        : df_v1,
    "Feuil1"                       : df_v1_Feuil1,
    "LEDD"                         : df_v1_LEDD,
    "PSYCHOTROPES"                 : df_v1_PSYCHOTROPES,
    "AUTRE_PARKINSON"              : df_v1_AUTRE_PARKINSON,
    "FREQUENCE"                    : df_v1_FREQUENCE,
    "CONSO_SPECIFIQUE"             : df_v1_CONSO_SPECIFIQUE,
    "DIGITSMT_TRAILMT_DKEFS"       : df_v1_DIGITSMT_TRAILMT_DKEFS,
    "PDQ39"                        : df_v1_PDQ39,
    "LARS"                         : df_v1_LARS,
    "HAMA"                         : df_v1_HAMA,
    "HAMD"                         : df_v1_HAMD,
    "MOCA"                         : df_v1_MOCA,
    "QUIP"                         : df_v1_QUIP,
    "ECMP"                         : df_v1_ECMP,
    "UPDRS"                        : df_v1_UPDRS,
    "Poids_Taille"                 : df_v1_Poids_Taille,
}

# ============================================================
#   GROUPE 3 : fichier vc.xlsx
# ============================================================
sheets_vc = {
    "DATES_VISITE"                 : df_vc_DATES_VISITE,
    "CONSO_SPECIFIQUE"             : df_vc_CONSO_SPECIFIQUE,
    "Feuil1"                       : df_vc_Feuil1,
    "LEDD"                         : df_vc_LEDD,
    "PSYCHOTROPES"                 : df_vc_PSYCHOTROPES,
    "AUTRE_PARKINSON"              : df_vc_AUTRE_PARKINSON,
    "CONSO_SPECIFIQUE"             : df_vc_CONSO_SPECIFIQUE,
}

# ============================================================
#   GROUPE 4 : fichier v3.xlsx
# ============================================================
sheets_v3 = {
    "DATES_VISITE"                 : df_v3_DATES_VISITE,
    "df_v3"                        : df_v3,
    "Feuil1"                       : df_v3_Feuil1,
    "LEDD"                         : df_v3_LEDD,
    "PSYCHOTROPES"                 : df_v3_PSYCHOTROPES,
    "AUTRE_PARKINSON"              : df_v3_AUTRE_PARKINSON,
    "FREQUENCE"                    : df_v3_FREQUENCE,
    "CONSO_SPECIFIQUE"             : df_v3_CONSO_SPECIFIQUE,
    "DIGITSMT_TRAILMT_DKEFS"       : df_v3_DIGITSMT_TRAILMT_DKEFS,
    "PDQ39"                        : df_v3_PDQ39,
    "LARS"                         : df_v3_LARS,
    "HAMA"                         : df_v3_HAMA,
    "HAMD"                         : df_v3_HAMD,
    "MOCA"                         : df_v3_MOCA,
    "QUIP"                         : df_v3_QUIP,
    "ECMP"                         : df_v3_ECMP,
    "UPDRSIII_COMPLET"             : df_v3_UPDRSIII_COMPLET,
    "UPDRS"                        : df_v3_UPDRS,
    "Poids_Taille"                 : df_v3_Poids_Taille,
}

# ============================================================
#   GROUPE 5 : fichier v5.xlsx
# ============================================================
sheets_v5 = {
    "DATES_VISITE"                 : df_v5_DATES_VISITE,
    "df_v5"                        : df_v5,
    "Feuil1"                       : df_v5_Feuil1,
    "LEDD"                         : df_v5_LEDD,
    "PSYCHOTROPES"                 : df_v5_PSYCHOTROPES,
    "AUTRE_PARKINSON"              : df_v5_AUTRE_PARKINSON,
    "FREQUENCE"                    : df_v5_FREQUENCE,
    "CONSO_SPECIFIQUE"             : df_v5_CONSO_SPECIFIQUE,
    "DIGITSMT_TRAILMT_DKEFS"       : df_v5_DIGITSMT_TRAILMT_DKEFS,
    "PDQ39"                        : df_v5_PDQ39,
    "LARS"                         : df_v5_LARS,
    "HAMA"                         : df_v5_HAMA,
    "HAMD"                         : df_v5_HAMD,
    "MOCA"                         : df_v5_MOCA,
    "QUIP"                         : df_v5_QUIP,
    "ECMP"                         : df_v5_ECMP,
    "UPDRSIII_COMPLET"             : df_v5_UPDRSIII_COMPLET,
    "UPDRS"                        : df_v5_UPDRS,
    "Poids_Taille"                 : df_v5_Poids_Taille,
}


# ─── Ne touche pas au code en dessous ───────────────────────

all_groups = {
    "V0" : sheets_V0,
    "v1" : sheets_v1,
    "vc" : sheets_vc,
    "v3" : sheets_v3,
    "v5" : sheets_v5,
}

for version, sheets in all_groups.items():
    filepath = f"{OUTPUT_DIR}/{version}.xlsx"
    with pd.ExcelWriter(filepath, engine="openpyxl") as writer:
        for sheet_name, df in sheets.items():
            df.to_excel(writer, sheet_name=sheet_name[:31], index=False)
    print(f"[OK] {filepath}  →  {len(sheets)} feuilles")
# Out:
# [OK] Output/V0.xlsx  →  16 feuilles
# [OK] Output/v1.xlsx  →  18 feuilles
# [OK] Output/vc.xlsx  →  6 feuilles
# [OK] Output/v3.xlsx  →  19 feuilles
# [OK] Output/v5.xlsx  →  19 feuilles

# %%
df

# %% [markdown]
# ### Bilan V0

# %%
df_V0 = pd.read_excel("Data/Matthieu_Soumaya_Dec2025.xlsx", sheet_name="Poids_Taille V0")
print(df_V0.shape)
df_V0.head()
# Out:
# (836, 7)
#                              SUBJID           INIT_PAT                TITRE  \
# 0  Subject Identifier for the Study  initiales patient                titre
# 1                            01-001                 SR  Visite de screening
# 2                            01-002                 TM  Visite de screening
# 3                            01-003                 SJ  Visite de screening
# 4                            01-004                 DJ  Visite de screening
#
#    POIDS           POIDS_NR  TAILLE           TAILLE_NR
# 0  poids  poids non réalisé  taille  taille non réalisé
# 1     76                NaN     171                 NaN
# 2     88                NaN     180                 NaN
# 3     89                NaN     176                 NaN
# 4     59                NaN     163                 NaN

# %%
# Out:
# (3341, 10)
#                              SUBJID           INIT_PAT  \
# 0  Subject Identifier for the Study  initiales patient
# 1                            01-001                 SR
# 2                            01-001                 SR
# 3                            01-001                 SR
# 4                            01-001                 SR
#
#                        TITRE     MDSUPDRSPARTIE4      MDSUPDRSPARTIE41  \
# 0                      titre  MDS-UPDRS partie 4  MDS-UPDRS partie 4.1
# 1        Visite de screening                  10                Minime
# 2   Visite Bilan à 1 an - V1                 NaN                   NaN
# 3  Visite Bilan à 3 ans - V3                 NaN                   NaN
# 4  Visite Bilan à 5 ans - V5                 NaN                   NaN
#
#        MDSUPDRSPARTIE42      MDSUPDRSPARTIE43      MDSUPDRSPARTIE44  \
# 0  MDS-UPDRS partie 4.2  MDS-UPDRS partie 4.3  MDS-UPDRS partie 4.4
# 1                Modéré                 Léger                Modéré
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#        MDSUPDRSPARTIE45      MDSUPDRSPARTIE46
# 0  MDS-UPDRS partie 4.5  MDS-UPDRS partie 4.6
# 1                Minime                Normal
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
